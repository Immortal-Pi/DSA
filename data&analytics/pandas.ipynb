# %%
import pandas as pd

# %%
# Series
data=[1,2,3,4,5]
series=pd.Series(data)
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
data=[20,304,50,40]
index=['a','b','c','d']
data1=pd.Series(data,index=index)

# %%
# from dictionaries 
data={
    'Name':['Amruth','Akshath','Thukaram','veena'],
    'Age':[29,28,69,65],
    'City':['Bangalore','New York', 'Florida','Texas']
}
data_pd=pd.DataFrame(data)
data_pd
# Out:
#        Name  Age       City
# 0    Amruth   29  Bangalore
# 1   Akshath   28   New York
# 2  Thukaram   69    Florida
# 3     veena   65      Texas

# %%
data=pd.read_csv('datasets/data_center_hybrid.csv')
data.head()
# Out:
#    Year  Facility_ID               Facility_Name Owner_Company    City  \
# 0  2019  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
# 1  2020  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
# 2  2021  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
# 3  2022  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
# 4  2023  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
#
#   Country        Facility_Type  Estimated_Capacity_MW    PUE  \
# 0   Spain  Enterprise/Standard                   6.24  1.975
# 1   Spain  Enterprise/Standard                   6.36  1.967
# 2   Spain  Enterprise/Standard                   6.47  1.928
# 3   Spain  Enterprise/Standard                   6.59  1.897
# 4   Spain  Enterprise/Standard                   6.70  1.869
#
#   Cooling_System_Type  WUE_L_per_kWh  Daily_Electricity_Usage_MWh  \
# 0         Evaporative          1.481                       183.62
# ...

# %%
print(len(data['Country'].unique()))
df=data[data['Country']=='United States'].reset_index()
df.drop('index',axis=1,inplace=True)
df.head()
# Out:
# 344
#    Year  Facility_ID               Facility_Name Owner_Company City  \
# 0  2019  DC-1B753A37  Silicon Valley Data Center      Fibernet  San
# 1  2020  DC-1B753A37  Silicon Valley Data Center      Fibernet  San
# 2  2021  DC-1B753A37  Silicon Valley Data Center      Fibernet  San
# 3  2022  DC-1B753A37  Silicon Valley Data Center      Fibernet  San
# 4  2023  DC-1B753A37  Silicon Valley Data Center      Fibernet  San
#
#          Country        Facility_Type  Estimated_Capacity_MW    PUE  \
# 0  United States  Enterprise/Standard                   4.39  1.547
# 1  United States  Enterprise/Standard                   4.50  1.536
# 2  United States  Enterprise/Standard                   4.63  1.527
# 3  United States  Enterprise/Standard                   4.75  1.501
# 4  United States  Enterprise/Standard                   4.88  1.471
#
#   Cooling_System_Type  WUE_L_per_kWh  Daily_Electricity_Usage_MWh  \
# 0         Evaporative          2.340                       117.57
# ...

# %% [markdown]
# ## loc and iloc
# - loc = row numbers and column names
# - iloc - pass the indexes only

# %%
df.loc[0:20,['Year','Facility_Name','Country']].head()
# Out:
#    Year               Facility_Name        Country
# 0  2019  Silicon Valley Data Center  United States
# 1  2020  Silicon Valley Data Center  United States
# 2  2021  Silicon Valley Data Center  United States
# 3  2022  Silicon Valley Data Center  United States
# 4  2023  Silicon Valley Data Center  United States

# %%
df.iloc[0:20,[1,2,5]].head(3)
# Out:
#    Facility_ID               Facility_Name        Country
# 0  DC-1B753A37  Silicon Valley Data Center  United States
# 1  DC-1B753A37  Silicon Valley Data Center  United States
# 2  DC-1B753A37  Silicon Valley Data Center  United States

# %%
df.iloc[0:20,1:5].head()
# Out:
#    Facility_ID               Facility_Name Owner_Company City
# 0  DC-1B753A37  Silicon Valley Data Center      Fibernet  San
# 1  DC-1B753A37  Silicon Valley Data Center      Fibernet  San
# 2  DC-1B753A37  Silicon Valley Data Center      Fibernet  San
# 3  DC-1B753A37  Silicon Valley Data Center      Fibernet  San
# 4  DC-1B753A37  Silicon Valley Data Center      Fibernet  San

# %%
# accessing a specific element 
df.at[2,'City'], df.iloc[2:4,4:5]
# Out:
# ('San',
#    City
#  2  San
#  3  San)

# %%
# create new columns 
df[df['Cooling_System_Type'].isin(['Air Cooled','Liquid Cooled'])].head()
# Out:
#     Year  Facility_ID Facility_Name   Owner_Company    City        Country  \
# 14  2019  DC-7AD2ECD4  1 Summer St.  Zayo Group LLC  Boston  United States
# 15  2020  DC-7AD2ECD4  1 Summer St.  Zayo Group LLC  Boston  United States
# 16  2021  DC-7AD2ECD4  1 Summer St.  Zayo Group LLC  Boston  United States
# 17  2022  DC-7AD2ECD4  1 Summer St.  Zayo Group LLC  Boston  United States
# 18  2023  DC-7AD2ECD4  1 Summer St.  Zayo Group LLC  Boston  United States
#
#           Facility_Type  Estimated_Capacity_MW    PUE Cooling_System_Type  \
# 14  Enterprise/Standard                  13.54  1.695          Air Cooled
# 15  Enterprise/Standard                  13.91  1.690          Air Cooled
# 16  Enterprise/Standard                  14.28  1.670          Air Cooled
# 17  Enterprise/Standard                  14.67  1.656          Air Cooled
# 18  Enterprise/Standard                  15.07  1.647          Air Cooled
#
# ...

# %%
df['Average_Monthly_Water_Usage']=df['Daily_Water_Usage_Gallons']*30
df
# Out:
#        Year  Facility_ID               Facility_Name Owner_Company     City  \
# 0      2019  DC-1B753A37  Silicon Valley Data Center      Fibernet      San
# 1      2020  DC-1B753A37  Silicon Valley Data Center      Fibernet      San
# 2      2021  DC-1B753A37  Silicon Valley Data Center      Fibernet      San
# 3      2022  DC-1B753A37  Silicon Valley Data Center      Fibernet      San
# 4      2023  DC-1B753A37  Silicon Valley Data Center      Fibernet      San
# ...     ...          ...                         ...           ...      ...
# 61721  2021  DC-9C4709FE         Bozeman Data Center    Vision Net  Unknown
# 61722  2022  DC-9C4709FE         Bozeman Data Center    Vision Net  Unknown
# 61723  2023  DC-9C4709FE         Bozeman Data Center    Vision Net  Unknown
# 61724  2024  DC-9C4709FE         Bozeman Data Center    Vision Net  Unknown
# 61725  2025  DC-9C4709FE         Bozeman Data Center    Vision Net  Unknown
#
# ...

# %%
df.groupby('Cooling_System_Type')['Daily_Water_Usage_Gallons'].mean()
# Out:
# Cooling_System_Type
# Air Cooled        14326.984248
# Evaporative      453269.816744
# Liquid Cooled     59104.537224
# Name: Daily_Water_Usage_Gallons, dtype: float64
