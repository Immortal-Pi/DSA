# %% [markdown]
# # Array

# %%
l1=[]

l1.append(1)
l1.append(1.5)
l1.append('python')
l1
# Out:
# [1, 1.5, 'python']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import array

arr=array.array('i',[1,2,3,4,5])
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
arr[0]
# Out:
# 1
