# %%
# lambda function 
eval=lambda num:num%2==0 
print(eval(31))
# Out:
# False

# %%
# leap year 
is_leap=lambda year:year%4==0 and (year%100!=0 or year%400==0)
print(is_leap(2026))
# Out:
# False

# %%
numbers=[2,4,5,31,2,12]
ans=map(eval,numbers)
for i in ans:
    print(i)
# Out:
# True
# True
# False
# False
# True
# True
