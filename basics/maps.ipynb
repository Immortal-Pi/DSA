# %%
import pandas as pd 
import numpy as np

# %%
a=np.array([2,3,4,5,7,0,2])
b=np.array([2,3,4,5,7,0,2])
fun=lambda num:np.sin(num)

t=map(fun,a+b)

# %%
for i in t:
    print(i)
# Out:
# -0.7568024953079282
# -0.27941549819892586
# 0.9893582466233818
# -0.5440211108893698
# 0.9906073556948704
# 0.0
# -0.7568024953079282

# %%
np.sin(a)
# Out:
# array([ 0.90929743,  0.14112001, -0.7568025 , -0.95892427,  0.6569866 ,
#         0.        ,  0.90929743])

# %%
adress=[
    {'name':'amruth'},
    {'name':'aksharth'},
    {'name':'veena'},
    {'name':'thukaram'}
]

def get_names(adress):
    return adress['name']

a=map(get_names,adress)
for i in a:
    print(i)
# Out:
# amruth
# aksharth
# veena
# thukaram
