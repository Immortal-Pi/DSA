# %%
class Node:
    def __init__(self,value):
        self.val=value 
        self.next=None
        self.prev=None 

class DoubleLL:
    def __init__(self,value):
        self.head=Node(value)
        self.tail=self.head
