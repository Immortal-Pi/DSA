# %% [markdown]
# # next greatest element
#
# Description:
# You are given an array a of size n. For each element in the array, find and print the Next Greater Element (NGE). The Next Greater Element for a given element x is the first element that is greater than x on its right side in the array. If no such element exists, return -1 for that position.
#
# Parameters:
#
# a (List of integers): The array of integers where you will search for the Next Greater Element.
#
# n (Integer): The size of the array a.
#
# Returns:
#
# A list of integers where each element represents the Next Greater Element of the corresponding element in the input array. If no such greater element exists, return -1.
#
# Examples:
#
# Input:
#
# a = [4, 5, 2, 25]
#
# n = 4
#
#
#
# Output:
#
# [5, 25, 25, -1]
#
# Disclaimer:
#
# This Udemy coding exercise is still in development. Some advanced cases may not be fully checked. Please use it primarily for basic code validation.
#
# Leetcode Link : https://leetcode.com/problems/next-greater-element-i/description/

# %%
def next_greater_element(a, n):
    # TODO: Implement this function
    ans=[]
    stack=[]
    i=n-1
    while i>=0:
        if len(stack)==0:
            ans.append(-1)
            stack.append(a[i])
 
        elif len(stack)!=0 and a[i]<stack[-1]:
            ans.append(stack[-1])
            stack.append(a[i])
        else:
            stack.pop()
            i+=1
        i-=1    
        print(stack,ans,a[i])
    return ans[::-1]

# %%
next_greater_element([4,5,2,25],4)
# Out:
# [25] [-1] 2
# [25, 2] [-1, 25] 5
# [25] [-1, 25] 5
# [25, 5] [-1, 25, 25] 4
# [25, 5, 4] [-1, 25, 25, 5] 25
# [5, 25, 25, -1]

# %% [markdown]
# # leetcode
# https://leetcode.com/problems/next-greater-element-i/description/

# %%
def nextGreaterElement( nums1, nums2):
        """
        :type nums1: List[int]
        :type nums2: List[int]
        :rtype: List[int]
        """
        ans={}
        stack=[]
        i=len(nums2)-1
        while i>=0:
            if len(stack)==0:
                ans[nums2[i]]=-1
                # ans.append(-1)
                stack.append(nums2[i])
    
            elif len(stack)!=0 and nums2[i]<stack[-1]:
                ans[nums2[i]]=stack[-1]
                # ans.append(stack[-1])
                stack.append(nums2[i])
            else:
                stack.pop()
                i+=1
            i-=1    
        final_ans=[]
        for i in nums1:
            final_ans.append(ans[i])
        return final_ans

# %% [markdown]
# # Valid Panthesis

# %%
def is_balanced(S):
    #Write down your code here
    stack=[]
    mapping={')':'(','}':'{',']':'['}
    for s in S:
        if s in mapping.values():
            stack.append(s)
        if s in mapping:
            if not stack or mapping[s]!=stack.pop():
                return False
    return not stack

# %%
is_balanced('{(((())))}')
# Out:
# True
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# remove consecutive duplicates

# %%
def removeDuplicates(s: str) -> str:
    #Write your code here
    stack=[]
    for i in s:
        if len(stack)>0 and i==stack[-1]:
            stack.pop()
        else:
            stack.append(i)
    # print(stack)
    return ''.join(stack)

# %%
removeDuplicates('azxxzy')
# Out:
# 'ay'

# %% [markdown]
# # next smallest element
#
# Input: arr = [10, 20, 30, 40]
# Output: [-1, -1, -1, -1]
#
# Input: arr = [1, 3, 2, 4]
# Output: [-1, 2, -1, -1]
#
# Input: arr = [4, 5, 2, 10, 8]
# Output: [2, 2, -1, 8, -1]

# %%
def next_smallest_element(arr):
    n=len(arr)-1
    ans=[]
    stack=[]
    while n>=0:
        if len(stack)==0:
            stack.append(arr[n])
            ans.append(-1)
        elif len(stack)>0 and arr[n]<stack[-1]:
            stack.pop()
            n+=1
        else:
            ans.append(stack[-1])
            stack.append(arr[n])
        n-=1
    return ans[::-1]

# %%
print(next_smallest_element([10,20,30,40]))
print(next_smallest_element([1,3,2,4]))
print(next_smallest_element([4,5,2,10,8]))
# Out:
# [-1, -1, -1, -1]
# [-1, 2, -1, -1]
# [2, 2, -1, 8, -1]

# %% [markdown]
# # evaluate postfix expression
#
# Input: expression = ["4", "13", "5", "/", "+"]
# Output: 6
#
# Input: expression = ["2", "1", "+", "3", "*"]
# Output: 9
#
# Input: expression = ["10", "6", "9", "3", "+", "-11", "*", "/", "*", "17", "+", "5", "+"]
# Output: 22

# %%
def evaluate_postfix(expression):
    """
    Function to evaluate a postfix expression.
    :param expression: List[str] -> A list of strings representing the postfix expression
    :return: int -> The result of the postfix evaluation
    """
    # TODO: Implement this function 
    stack=[]
    i=0
    while i<len(expression):
        if expression[i]=='*':
                elem1=int(stack.pop())
                elem2=int(stack.pop())
                ans=elem2*elem1   
                stack.append(ans)
        elif expression[i]=='+':
                elem1=int(stack.pop())
                elem2=int(stack.pop())
                ans=elem2+elem1   
                stack.append(ans)
        elif expression[i]=='-':
                elem1=int(stack.pop())
                elem2=int(stack.pop())
                ans=elem2-elem1   
                stack.append(ans)
        elif expression[i]=='/':
                elem1=int(stack.pop())
                elem2=int(stack.pop())
                ans=int(elem2/elem1)   
                print(ans)
                stack.append(ans)
        else:
            stack.append(expression[i])
        i+=1
        print(stack)
    return stack[-1]

# %%
evaluate_postfix(["10","6","9","3","+","-11","*","/","*","17","+","5","+"])
# Out:
# ['10']
# ['10', '6']
# ['10', '6', '9']
# ['10', '6', '9', '3']
# ['10', '6', 12]
# ['10', '6', 12, '-11']
# ['10', '6', -132]
# 0
# ['10', 0]
# [0]
# [0, '17']
# [17]
# [17, '5']
# [22]
# 22

# %% [markdown]
# # winner of the circular game
#
# Description:
#
# There are n friends sitting in a circle numbered from 1 to n. They play a game with the following rules:
#
# Start at the 1st friend.
#
# Count k friends in a clockwise direction, including the starting friend. The counting wraps around the circle.
#
# The friend at the k-th position leaves the circle.
#
# If more than one friend remains, continue from the friend immediately clockwise of the one who just left.
#
# The last remaining friend is the winner.
#
# Given the number of friends n and an integer k, return the winner of the game.
#
#
#
# Input:
#
# n (1 ≤ n ≤ 10^5): The number of friends.
#
# k (1 ≤ k ≤ 10^5): The counting number.
#
# Output:
#
# An integer representing the winner of the game.
#
#
#
# Example:
#
# Input: n = 5, k = 3
# Output: 4
#
# Explanation: The elimination order is 3, 4, 5, 1, so the last remaining friend is 2.

# %%
from collections import deque
def find_winner(n,k):
    elements=[]
    buf=deque(range(1,n+1))
    while len(buf)>1:
        buf.rotate(-(k-1))
        buf.popleft()
        print(buf)
    return buf[0]

# %%
# solution2 
def find_winner(n,k):
    elements=[]
    buf=[i for i in range(1,n+1)]
   
    while len(buf)>1:
        temp=buf[k-1:]+buf[:k-1]
        buf=temp[1:]
        # print(buf)
    return buf[0]

# %%
find_winner(5,3)
# Out:
# 4

# %% [markdown]
# # Largest rectangle in Histogram

# %%
def get_largest_rectangle(heights):
    max_area=0
    stack=[]
    n=len(heights)
    for i in range(n+1):
        current_height=heights[i] if i<n else 0
        while stack and heights[stack[-1]]>current_height:
            top=stack.pop()
            height=heights[top]
            width=i if not stack else i-stack[-1]-1
            max_area=max(max_area,height*width)
        stack.append(i)
    return max_area

# %%
get_largest_rectangle([2, 1, 5, 6, 2, 3])

# %%
# implement stack as queue

# %%
class MyStack(object):

    def __init__(self):
        self.stack=[]
        

    def push(self, x):
        """
        :type x: int
        :rtype: None
        """
        self.stack.append(x)

        

    def pop(self):
        """
        :rtype: int
        """
        if len(self.stack)>0:
            
            return self.stack.pop()
        else:
            return -1 
        

    def top(self):
        """
        :rtype: int
        """
        return self.stack[-1] if self.stack else -1 
        

    def empty(self):
        """
        :rtype: bool
        """
        return True if len(self.stack)>0 else False
        


# Your MyStack object will be instantiated and called as such:
# obj = MyStack()
# obj.push(x)
# param_2 = obj.pop()
# param_3 = obj.top()
# param_4 = obj.empty()

# %%
myStack = MyStack()
myStack.push(1)
myStack.push(2)
print(myStack.stack)
print(myStack.top())
myStack.pop()
myStack.empty()
# Out:
# [1, 2]
# 2
# True

# %% [markdown]
# # LRU Cache
# ![image.png](attachment:image.png)

# %%
class Node:
    def __init__(self,key,value):
        self.key=key
        self.value=value 
        self.next=None 
        self.prev=None 

class LRUCache(object):

    def __init__(self, capacity):
        """
        :type capacity: int
        """
        self.cache={}
        self.capacity=capacity 

        self.head=Node(-1,-1)
        self.tail=Node(-1,-1)
        self.head.next=self.tail
        self.tail.prev=self.head 

    def insertToFront(self,node):
        node.next=self.head.next 
        self.head.next.prev=node 
        node.prev=self.head 
        self.head.next=node

    def remove(self,node):
        node.prev.next=node.next 
        node.next.prev=node.prev          

    def get(self, key):
        """
        :type key: int
        :rtype: int
        """
        if key not in self.cache:
            return -1 
        node=self.cache[key]
        self.remove(node)
        self.insertToFront(node)
        return node.value
        

    def put(self, key, value):
        """
        :type key: int
        :type value: int
        :rtype: None
        """
        if key in self.cache:
            node=self.cache[key]
            node.value=value 
            self.remove(node)
            self.insertToFront(node)

        else:
            if len(self.cache)==self.capacity:
                lru=self.tail.prev
                del self.cache[lru.key]
                self.remove(lru)

            
            node=Node(key,value)
            self.cache[key]=node
            self.insertToFront(node)
        


lRUCache = LRUCache(2);
lRUCache.put(1, 1); # cache is {1=1}
lRUCache.put(2, 2); # cache is {1=1, 2=2}
lRUCache.get(1);    # return 1
lRUCache.put(3, 3); # LRU key was 2, evicts key 2, cache is {1=1, 3=3}
lRUCache.get(2);    # returns -1 (not found)
lRUCache.put(4, 4); # LRU key was 1, evicts key 1, cache is {4=4, 3=3}
lRUCache.get(1);    # return -1 (not found)
lRUCache.get(3);    # return 3
lRUCache.get(4);    # return 4

# %%
# using traditional arrays but time complexity is always O(n)
class LRUCache(object):

    def __init__(self, capacity):
        """
        :type capacity: int
        """
        self.cache={}
        self.current_capacity=0
        self.capacity=capacity
        self.useage=[]
        

    def get(self, key):
        """
        :type key: int
        :rtype: int
        """
        if key in self.cache:
            self.useage.remove(key)
            self.useage.append(key)
            # print(self.useage)
            return self.cache[key]
        return -1     

    def put(self, key, value):
        """
        :type key: int
        :type value: int
        :rtype: None
        """
        if self.current_capacity<self.capacity and key not in self.cache.keys():
            self.cache[key]=value
            self.current_capacity+=1 
            self.useage.append(key)
        elif key in self.cache.keys():
            self.cache[key]=value
            self.useage.remove(key)
            self.useage.append(key)
            
        elif self.current_capacity==self.capacity and key not in self.cache.keys():
            changing_key=self.useage[0]
            # print(changing_key)
            self.cache.pop(changing_key)
            self.cache[key]=value
            self.useage.remove(changing_key)
            self.useage.append(key)
        print(self.cache,self.useage)


# Your LRUCache object will be instantiated and called as such:
# obj = LRUCache(capacity)
# param_1 = obj.get(key)
# obj.put(key,value)

# %% [markdown]
# # next greater element in circular list
# ![image.png](attachment:image.png)

# %%
def nextGreaterElement(nums):
    n=len(nums)
    result=[-1]*n
    stack=[]
    for i in range(2*n-1,-1,-1):
        num=nums[i%n]
        while stack and stack[-1]<=num:
            stack.pop()
        if stack:
            result[i%n]=stack[-1]
        stack.append(nums[i%n])
        print(stack,result)

# %%
nextGreaterElement([1,2,3,4,3])
# Out:
# [3] [-1, -1, -1, -1, -1]
# [4] [-1, -1, -1, -1, -1]
# [4, 3] [-1, -1, 4, -1, -1]
# [4, 3, 2] [-1, 3, 4, -1, -1]
# [4, 3, 2, 1] [2, 3, 4, -1, -1]
# [4, 3] [2, 3, 4, -1, 4]
# [4] [2, 3, 4, -1, 4]
# [4, 3] [2, 3, 4, -1, 4]
# [4, 3, 2] [2, 3, 4, -1, 4]
# [4, 3, 2, 1] [2, 3, 4, -1, 4]
