# %%
import pandas as pd 
import os 
import time

# %%
# linear search
def linear_search(arr,num):
    for i in range(len(arr)):
        if arr[i]==num:
            return i 
    return -1

# %%
# binary search

# %%
linear_search([99,22,44,1,2,7,3,4,0],22)
